# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\mikel\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (9.5.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\MIKEL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import mysql.connector as connector

# %% [markdown]
# # 1. Connection to a MySQL database

# %%
connection = connector.connect(
    user="root",
    password="",# añadir la passwqord
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 connection = connector.connect(
#       2     user="root",
#       3     password="",# añadir la passwqord
#       4 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\connection.py:388, in MySQLConnection._open_connection(self)
#     385 self._do_handshake()
#     387 # start authentication negotiation
# --> 388 self._do_auth(
#     389     self._user,
#     390     self._password,
#     391     self._database,
#     392     self._client_flags,
#     393     self._ssl,
#     394     self._conn_attrs,
#     395 )
#     396 self.converter_class = self._converter_class
#     398 if self._client_flags & ClientFlag.COMPRESS:
#     399     # update the network layer accordingly
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\connection.py:320, in MySQLConnection._do_auth(self, username, password, database, client_flags, ssl_options, conn_attrs)
#     309 # Add the custom configurations required by specific auth plugins
#     310 self._authenticator.update_plugin_config(
#     311     config={
#     312         "krb_service_principal": self._krb_service_principal,
#    (...)
#     317     }
#     318 )
# --> 320 ok_pkt = self._authenticator.authenticate(
#     321     sock=self._socket,
#     322     handshake=self._handshake,
#     323     username=username,
#     324     password1=password,
#     325     password2=self._password2,
#     326     password3=self._password3,
#     327     database=database,
#     328     charset=self._charset_id,
#     329     client_flags=client_flags,
#     330     auth_plugin=self._auth_plugin,
#     331     auth_plugin_class=self._auth_plugin_class,
#     332     conn_attrs=conn_attrs,
#     333 )
#     334 self._handle_ok(ok_pkt)
#     336 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\authentication.py:381, in MySQLAuthenticator.authenticate(self, sock, handshake, username, password1, password2, password3, database, charset, client_flags, max_allowed_packet, auth_plugin, auth_plugin_class, conn_attrs, is_change_user_request, read_timeout, write_timeout)
#     378 # server replies back
#     379 pkt = bytes(sock.recv(read_timeout))
# --> 381 ok_pkt = self._handle_server_response(sock, pkt)
#     382 if ok_pkt is None:
#     383     raise InterfaceError("Got a NULL ok_pkt") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mysql\connector\authentication.py:287, in MySQLAuthenticator._handle_server_response(self, sock, pkt)
#     284     return self._mfa_n_factor(sock, pkt)
#     286 if pkt[4] == ERR_STATUS:
# --> 287     raise get_exception(pkt)
#     289 return None
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
try:
    connection=connector.connect(
        user="wrong_user",
        password='wrong_password'
    )
except:
    print("""
    There was a problem connecting to the database.
    Please check your username or the password.
    """)
# Out:
#     There was a problem connecting to the database.
#     Please check your username or the password.

# %%
try:
    connection=connector.connect(
        user="ameta",
        password="password",
        database = "no_database")

except connector.Error as er:
    print("Error code:", er.errno)
    print("Error message:", er.msg)
# Out:
# Error code: 1045
# Error message: Access denied for user 'ameta'@'localhost' (using password: YES)

# %%
# Let's close the cursor and the connection
if connection.is_connected():
    connection.close()
    print("MySQL connection is closed.")
else:
    print("Connection is already closed")
# Out:
# Connection is already closed

# %% [markdown]
# # 2. Creating a database and tables

# %%
connection = connector.connect(
    user="root",
    password="",# añadir la passwqord
)

# %%
cursor = connection.cursor()

# %%
create_database_query = "CREATE DATABASE IF NOT EXISTS little_lemon"

# %%
cursor.execute(create_database_query)

# %%
use_database_query = "USE little_lemon"

# %%
cursor.execute(use_database_query)

# %%
create_menuitem_table_query = """
CREATE TABLE IF NOT EXISTS MenuItems (
ItemID INT PRIMARY KEY AUTO_INCREMENT,
Name VARCHAR(200) NOT NULL,
Type VARCHAR(100) NOT NULL,
Price INT NOT NULL
)
"""

# %%
cursor.execute(create_menuitem_table_query)

# %%
cursor.execute("show databases")
for database in cursor:
    print(database)
# Out:
# ('information_schema',)
# ('little_lemon',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
# checking connection status
connection.database
# Out:
# 'little_lemon'

# %%
cursor.execute("show tables;")
for table in cursor:
    print(table)
# Out:
# ('menuitems',)
# ('menus',)

# %%
create_menu_table_query = """
CREATE TABLE IF NOT EXISTS Menus (
MenuID INT AUTO_INCREMENT,
ItemID INT,
Cuisine VARCHAR(100) NOT NULL,
PRIMARY KEY (MenuID, ItemID)
)
"""

# %%
cursor.execute(create_menu_table_query)

# %%
cursor.execute("show tables")
for table in cursor:
    print(table)
# Out:
# ('menuitems',)
# ('menus',)

# %%
Create_booking_table = """CREATE TABLE Bookings (
BookingID INT AUTO_INCREMENT,
TableNo INT,
GuestFirstName VARCHAR(100) NOT NULL,
GuestLastName VARCHAR(100) NOT NULL,
BookingSlot TIME NOT NULL,
EmployeeID INT,
PRIMARY KEY (BookingID)
);"""

# %%
cursor.execute(Create_booking_table)

# %%
cursor.execute("show tables")
for table in cursor:
    print(table)
# Out:
# ('bookings',)
# ('menuitems',)
# ('menus',)

# %%
create_orders_table = """CREATE TABLE Orders (
OrderID INT,
TableNo INT,
MenuID INT,
BookingID INT,
BillAmount INT,
Quantity INT,
PRIMARY KEY (OrderID,TableNo)
);"""

# %%
cursor.execute(create_orders_table)

# %%
cursor.execute("show tables")
for table in cursor:
    print(table)
# Out:
# ('bookings',)
# ('menuitems',)
# ('menus',)
# ('orders',)
